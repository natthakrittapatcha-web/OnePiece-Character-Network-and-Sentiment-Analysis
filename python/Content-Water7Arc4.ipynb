# %%
# !pip install -q transformers

# %%
from transformers import RobertaTokenizerFast, TFRobertaForSequenceClassification, pipeline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sentiment_pipeline = pipeline("sentiment-analysis")
data = ["I love you", "I hate you"]
sentiment_pipeline(data)
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision 714eb0f (https://huggingface.co/distilbert/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/629 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Device set to use cpu
# [{'label': 'POSITIVE', 'score': 0.9998656511306763},
#  {'label': 'NEGATIVE', 'score': 0.9991129040718079}]

# %%
# download pre-trained emotion classification model
emotion = pipeline("text-classification", model="j-hartmann/emotion-english-distilroberta-base")

emotion(data)
# Out:
# config.json:   0%|          | 0.00/1.00k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/329M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/294 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/798k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# Device set to use cpu
# [{'label': 'joy', 'score': 0.9687249660491943},
#  {'label': 'anger', 'score': 0.6728214025497437}]

# %%
df = pd.read_csv('Water7.csv')

# %%
df.head(5)
# Out:
#   web-scraper-order                              web-scraper-start-url  \
# 0      1735058309-9  https://transcripts.foreverdreaming.org/viewfo...
# 1     1735058311-10  https://transcripts.foreverdreaming.org/viewfo...
# 2     1735058315-11  https://transcripts.foreverdreaming.org/viewfo...
# 3     1735058318-12  https://transcripts.foreverdreaming.org/viewfo...
# 4     1735058320-13  https://transcripts.foreverdreaming.org/viewfo...
#
#                                                 link  \
# 0   07x207 - Great Adventure in Long Ring Long Land!
# 1        07x208 - A Davy Back with the Foxy Pirates!
# 2       07x209 - Round 1! One Lap of the Donut Race!
# 3  07x210 - Silver Fox Foxy! The Merciless Interf...
# 4   07x211 - Round 2! sh**t It into the Groggy Ring!
#
#                                            link-href  \
# 0  https://transcripts.foreverdreaming.org/viewto...
# 1  https://transcripts.foreverdreaming.org/viewto...
# 2  https://transcripts.foreverdreaming.org/viewto...
# 3  https://transcripts.foreverdreaming.org/viewto...
# 4  https://transcripts.foreverdreaming.org/viewto...
#
#                                              comment
# 0  LONGRING LONGLAND!\n\n\n\n THE GREAT ADVENTURE...
# 1  PIRATE FOXY DAVY BACK FIGHT!\n\n\n\n !\n\n\n\n...
# 2  FIRST ROUND!\n\n\n\n THE DONUT RACE Brothel.\n...
# 3  FOXY THE SILVER FOX!\n\n\n\n AN INTERVENTION F...
# 4  Luffy accepted Davy Back Fight which opposes i...

# %%
df.drop(['web-scraper-order', 'web-scraper-start-url'], axis=1, inplace=True)

# %%
df.head(5)
# Out:
#                                                 link  \
# 0   07x207 - Great Adventure in Long Ring Long Land!
# 1        07x208 - A Davy Back with the Foxy Pirates!
# 2       07x209 - Round 1! One Lap of the Donut Race!
# 3  07x210 - Silver Fox Foxy! The Merciless Interf...
# 4   07x211 - Round 2! sh**t It into the Groggy Ring!
#
#                                            link-href  \
# 0  https://transcripts.foreverdreaming.org/viewto...
# 1  https://transcripts.foreverdreaming.org/viewto...
# 2  https://transcripts.foreverdreaming.org/viewto...
# 3  https://transcripts.foreverdreaming.org/viewto...
# 4  https://transcripts.foreverdreaming.org/viewto...
#
#                                              comment
# 0  LONGRING LONGLAND!\n\n\n\n THE GREAT ADVENTURE...
# 1  PIRATE FOXY DAVY BACK FIGHT!\n\n\n\n !\n\n\n\n...
# 2  FIRST ROUND!\n\n\n\n THE DONUT RACE Brothel.\n...
# 3  FOXY THE SILVER FOX!\n\n\n\n AN INTERVENTION F...
# 4  Luffy accepted Davy Back Fight which opposes i...

# %%
MAX_LENGTH = 512  # ขีดจำกัดของโมเดล
df['comment'] = df['comment'].apply(lambda x: x[:MAX_LENGTH] if isinstance(x, str) else "")
#ตัดข้อความให้สั้นลงก่อนประมวลผล

# %%
df['comment'] = df['comment'].str.replace('\n', '').str.replace('\r', '').str.replace('', '').str.replace('Fame', '').str.replace('Wealth', '').str.replace('Power', '').str.replace('', '')

# %%
df['sentiment'] = df.comment.apply(lambda x: sentiment_pipeline(x)[0]['label'])

# %%
df['emotion'] = df.comment.apply(lambda x: emotion(x)[0]['label'])

# %%
df.head(5)
# Out:
#                                                 link  \
# 0   07x207 - Great Adventure in Long Ring Long Land!
# 1        07x208 - A Davy Back with the Foxy Pirates!
# 2       07x209 - Round 1! One Lap of the Donut Race!
# 3  07x210 - Silver Fox Foxy! The Merciless Interf...
# 4   07x211 - Round 2! sh**t It into the Groggy Ring!
#
#                                            link-href  \
# 0  https://transcripts.foreverdreaming.org/viewto...
# 1  https://transcripts.foreverdreaming.org/viewto...
# 2  https://transcripts.foreverdreaming.org/viewto...
# 3  https://transcripts.foreverdreaming.org/viewto...
# 4  https://transcripts.foreverdreaming.org/viewto...
#
#                                              comment sentiment   emotion
# 0  LONGRING LONGLAND! THE GREAT ADVENTURE One mov...  NEGATIVE       joy
# 1  PIRATE FOXY DAVY BACK FIGHT! ! One is there, o...  NEGATIVE     anger
# 2  FIRST ROUND! THE DONUT RACE Brothel. This time...  NEGATIVE  surprise
# 3  FOXY THE SILVER FOX! AN INTERVENTION FORCES Th...  POSITIVE  surprise
# 4  Luffy accepted Davy Back Fight which opposes i...  NEGATIVE  surprise

# %%
sns.set(rc={'figure.figsize':(10,5)})
fig = sns.histplot(df['sentiment'])

# %%
sns.set(rc={'figure.figsize':(10,5)})
fig = sns.histplot(df['emotion'])

# %%
df.to_csv('SoothingRelaxation-done.csv', index=False)

# %%
from wordcloud import WordCloud
from wordcloud import STOPWORDS

# %%
# Wordcloud with positive
msg = df['comment'][df["sentiment"] == 'POSITIVE']
stop_words = list(STOPWORDS)
positive_wordcloud = WordCloud(max_font_size=50, max_words=100, background_color="white", stopwords = stop_words).generate(str(msg))
plt.figure()
plt.title("Positive Tweets - Wordcloud")
plt.imshow(positive_wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
 # Wordcloud with negative
msg = df['comment'][df["sentiment"] == 'NEGATIVE']
stop_words = ["https", "co", "RT"] + list(STOPWORDS)
negative_wordcloud = WordCloud(max_font_size=50, max_words=100, background_color="white", stopwords = stop_words).generate(str(msg))
plt.figure()
plt.title("Negative Tweets - Wordcloud")
plt.imshow(negative_wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
msg = df['comment']
stop_words = ["https", "co", "RT"] + list(STOPWORDS)
negative_wordcloud = WordCloud(max_font_size=50, max_words=100, background_color="white", stopwords = stop_words).generate(str(msg))
plt.figure()
plt.title("Negative Tweets - Wordcloud")
plt.imshow(negative_wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
msg = df['comment'][df['emotion'] == 'JOY']
stop_words = ["https", "co", "RT"] + list(STOPWORDS)
negative_wordcloud = WordCloud(max_font_size=50, max_words=100, background_color="white", stopwords = stop_words).generate(str(msg))
plt.figure()
plt.title("Negative Tweets - Wordcloud")
plt.imshow(negative_wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()
